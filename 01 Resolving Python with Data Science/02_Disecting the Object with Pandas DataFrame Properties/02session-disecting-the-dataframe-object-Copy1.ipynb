# %% [markdown]
# <font size="+5">#02 | Dissecting the Object with Pandas DataFrame Properties</font>

# %% [markdown]
# - Subscribe to my [Blog ↗](https://blog.pythonassembly.com/)
# - Let's keep in touch on [LinkedIn ↗](www.linkedin.com/in/jsulopz) 😄

# %% [markdown]
# ## All that glitters is not gold
#
# > - Not all objects can call the same functions
# > - Even though they may store the same information

# %% [markdown]
# ### `list`

# %% [markdown]
# > - Create a list with your math `grades`

# %%
lista_notas = [10, 7, 8]

# %% [markdown]
# > - Compute the mean

# %%
lista_notas.mean()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/24/tg28vxls25l9mjvqrnh0plc80000gn/T/ipykernel_34198/3880515775.py in <module>
# ----> 1 lista_notas.mean()
#
# AttributeError: 'list' object has no attribute 'mean'

# %% [markdown]
# > - You cannot do the mean
# > - But you could `sum()` and `len()`

# %%
sum(lista_notas)
# Out:
# 25

# %%
len(lista_notas)
# Out:
# 3

# %% [markdown]
# > - And divide the sum by the number of exams you did

# %%
sum(lista_notas)/len(lista_notas)
# Out:
# 8.333333333333334

# %% [markdown]
# > - [ ] Isn't it an `object` that could calculate the `mean()`?

# %% [markdown]
# ### `Series`

# %%
import pandas as pd

# %%
series_notas = pd.Series([10, 7, 8])

# %%
series_notas
# Out:
# 0    10
# 1     7
# 2     8
# dtype: int64

# %%
series_notas.mean()
# Out:
# 8.333333333333334

# %%
lista_notas
# Out:
# [10, 7, 8]

# %%
lista_notas.mean()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/24/tg28vxls25l9mjvqrnh0plc80000gn/T/ipykernel_34198/3880515775.py in <module>
# ----> 1 lista_notas.mean()
#
# AttributeError: 'list' object has no attribute 'mean'

# %%
type(notas_series)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/24/tg28vxls25l9mjvqrnh0plc80000gn/T/ipykernel_34198/1492223461.py in <module>
# ----> 1 type(notas_series)
#
# NameError: name 'notas_series' is not defined

# %%
type(notas)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/24/tg28vxls25l9mjvqrnh0plc80000gn/T/ipykernel_34198/3090815313.py in <module>
# ----> 1 type(notas)
#
# NameError: name 'notas' is not defined

# %% [markdown]
# > - Use the `.` + `[tab]` key to see the `functions/methods` of the object

# %%
notas.
# Out:
#   File "/var/folders/24/tg28vxls25l9mjvqrnh0plc80000gn/T/ipykernel_34198/3389551673.py", line 1
#     notas.
#           ^
# SyntaxError: invalid syntax

# %%
series_notas.
# Out:
#   File "/var/folders/24/tg28vxls25l9mjvqrnh0plc80000gn/T/ipykernel_34198/1457235964.py", line 1
#     series_notas.
#                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## How to Access the `items` of an `Object`

# %% [markdown]
# ### The `list`

# %% [markdown]
# > - Create a list of your best friends

# %%
lista_bf = ['maria', 'pepe', 'alberto']

# %% [markdown]
# > - Access the 2nd element `'pepe'` ↓

# %%
lista_bf[1]
# Out:
# 'pepe'

# %% [markdown]
# ### The `dict`

# %%
diccionario_bf = {'primera': 'maria', 'segundo': 'pepe', 'tercero': 'alberto'}

# %% [markdown]
# > - Access the 2nd element `'pepe'` ↓

# %%
diccionario_bf[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/24/tg28vxls25l9mjvqrnh0plc80000gn/T/ipykernel_34198/637862609.py in <module>
# ----> 1 diccionario_bf[1]
#
# KeyError: 1

# %%
diccionario_bf.keys()
# Out:
# dict_keys(['primera', 'segundo', 'tercero'])

# %%
diccionario_bf['segundo']
# Out:
# 'pepe'

# %% [markdown]
# ## Store the information in Python `objects` for the Best Tennis Players

# %% [markdown]
# > - income
# > - titles
# > - grand slams
# > - turned professional
# > - wins
# > - losses

# %% [markdown]
# ### Create a `dictionary` for Roger Federer

# %%
roger = {'income': 130, 'titles': 103, 'grand slams': 20, 'turned professional': 1998, 'wins': 1251, 'losses': 275}

# %%
roger
# Out:
# {'income': 130,
#  'titles': 103,
#  'grand slams': 20,
#  'turned professional': 1998,
#  'wins': 1251,
#  'losses': 275}

# %% [markdown]
# ### Create a `dictionary` for Rafa Nadal

# %%
rafa = {'income': 127, 'titles': 90, 'grand slams': 21, 'turned professional': 2001, 'wins': 1038, 'losses': 209}

# %%
rafa
# Out:
# {'income': 127,
#  'titles': 90,
#  'grand slams': 21,
#  'turned professional': 2001,
#  'wins': 1038,
#  'losses': 209}

# %% [markdown]
# ### Create a `dictionary` for Novak Djokovic

# %%
nole = {'income': 154, 'titles': 86, 'grand slams': 20, 'turned professional': 2003, 'wins': 989, 'losses': 199}

# %%
nole
# Out:
# {'income': 154,
#  'titles': 86,
#  'grand slams': 20,
#  'turned professional': 2003,
#  'wins': 989,
#  'losses': 199}

# %% [markdown]
# ### How much wealth did all of them earned?

# %% [markdown]
# > - You may put all of them into a `list`
# > - And `sum()` the `wealth`

# %%
lista_best_players = [roger, rafa, nole]

# %%
lista_best_players.sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/24/tg28vxls25l9mjvqrnh0plc80000gn/T/ipykernel_34198/1299779046.py in <module>
# ----> 1 lista_best_players.sum()
#
# AttributeError: 'list' object has no attribute 'sum'

# %% [markdown]
# > - The `sum()` is not an action
# > - that a simple object `list` can perform
# > - [ ] Could we convert the list into a
# > - more powerful object
# > - that could compute the `sum()`?

# %%
import pandas as pd

# %%
pd.DataFrame(lista_best_players)
# Out:
#    income  titles  grand slams  turned professional  wins  losses
# 0     130     103           20                 1998  1251     275
# 1     127      90           21                 2001  1038     209
# 2     154      86           20                 2003   989     199

# %%
df_best_players = pd.DataFrame(lista_best_players, index=['roger', 'rafa', 'nole'])

# %%
df_best_players
# Out:
#        income  titles  grand slams  turned professional  wins  losses
# roger     130     103           20                 1998  1251     275
# rafa      127      90           21                 2001  1038     209
# nole      154      86           20                 2003   989     199

# %% [markdown]
# > - Access the `wealth` column
# > - and compute the `sum()`

# %%
df_best_players['wealth']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniforge3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/miniforge3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/miniforge3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'wealth'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/24/tg28vxls25l9mjvqrnh0plc80000gn/T/ipykernel_34198/4096834809.py in <module>
# ----> 1 df_best_players['wealth']
#
# ~/miniforge3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/miniforge3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'wealth'

# %%
df_best_players['wealth'].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniforge3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/miniforge3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/miniforge3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'wealth'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/24/tg28vxls25l9mjvqrnh0plc80000gn/T/ipykernel_34198/2545408352.py in <module>
# ----> 1 df_best_players['wealth'].sum()
#
# ~/miniforge3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/miniforge3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'wealth'

# %% [markdown]
# > - [ ] Which type of `object` is the table?

# %%
type(df_best_players)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# > - [ ] What else can we do with this `object`?

# %%
df_best_players.
# Out:
#   File "/var/folders/24/tg28vxls25l9mjvqrnh0plc80000gn/T/ipykernel_34198/4064718670.py", line 1
#     df_best_players.
#                     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Can we select specific parts of the `DataFrame`?

# %% [markdown]
# > - [ ] names of rows

# %%
df_best_players.index
# Out:
# Index(['roger', 'rafa', 'nole'], dtype='object')

# %% [markdown]
# > - [ ] names of columns

# %%
df_best_players.columns
# Out:
# Index(['income', 'titles', 'grand slams', 'turned professional', 'wins',
#        'losses'],
#       dtype='object')

# %% [markdown]
# > - [ ] number of rows & columns

# %%
df_best_players.shape
# Out:
# (3, 6)

# %% [markdown]
# ## Vocabulary Recap
#
# 1. object/
# 2. function/method
# 3. parameter/argument
# 4. library

# %% [markdown]
# ## A practical case
#
# > - Retrieve information from an url
# > - and convert it into a DataFrame
# > - to operate with the Data

# %% [markdown]
# ### Retrieve the Information from an `url`

# %% [markdown]
# https://github.com/jsulopz/data

# %% [markdown]
# > - Find the `function()` that gets the content from an `url`

# %%
import requests

res = requests.get('https://raw.githubusercontent.com/jsulopz/data/main/best_tennis_players_stats.json')
res
# Out:
# <Response [200]>

# %% [markdown]
# > - Is the object just `<Response [200]>`
# > - Or may it contain more information/data?

# %%
res.
# Out:
#   File "/var/folders/24/tg28vxls25l9mjvqrnh0plc80000gn/T/ipykernel_34198/1459325066.py", line 1
#     res.
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# > - How can you access the data we see [here](https://raw.githubusercontent.com/jsulopz/data/main/best_tennis_players_stats.json)

# %%
res.content
# Out:
# b'{"income":{"roger":130,"rafa":127,"nole":154},"titles":{"roger":103,"rafa":90,"nole":86},"grand slams":{"roger":20,"rafa":21,"nole":20},"turned professional":{"roger":1998,"rafa":2001,"nole":2003},"wins":{"roger":1251,"rafa":1038,"nole":989},"losses":{"roger":275,"rafa":209,"nole":199}}'

# %%
pd.DataFrame(res.content)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/24/tg28vxls25l9mjvqrnh0plc80000gn/T/ipykernel_34198/1980481689.py in <module>
# ----> 1 pd.DataFrame(res.content)
#
# ~/miniforge3/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     728         else:
#     729             if index is None or columns is None:
# --> 730                 raise ValueError("DataFrame constructor not properly called!")
#     731
#     732             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#
# ValueError: DataFrame constructor not properly called!

# %%
pd.DataFrame('{"income":{"roger":130,"rafa":127,"nole":154},"titles":{"roger":103,"rafa":90,"nole":86},"grand slams":{"roger":20,"rafa":21,"nole":20},"turned professional":{"roger":1998,"rafa":2001,"nole":2003},"wins":{"roger":1251,"rafa":1038,"nole":989},"losses":{"roger":275,"rafa":209,"nole":199}}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/24/tg28vxls25l9mjvqrnh0plc80000gn/T/ipykernel_34198/858571472.py in <module>
# ----> 1 pd.DataFrame('{"income":{"roger":130,"rafa":127,"nole":154},"titles":{"roger":103,"rafa":90,"nole":86},"grand slams":{"roger":20,"rafa":21,"nole":20},"turned professional":{"roger":1998,"rafa":2001,"nole":2003},"wins":{"roger":1251,"rafa":1038,"nole":989},"losses":{"roger":275,"rafa":209,"nole":199}}')
#
# ~/miniforge3/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     728         else:
#     729             if index is None or columns is None:
# --> 730                 raise ValueError("DataFrame constructor not properly called!")
#     731
#     732             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#
# ValueError: DataFrame constructor not properly called!

# %%
pd.DataFrame('{"nombres": ["juan", "pepe"], "peso": [67,45]}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/24/tg28vxls25l9mjvqrnh0plc80000gn/T/ipykernel_34198/3146940143.py in <module>
# ----> 1 pd.DataFrame('{"nombres": ["juan", "pepe"], "peso": [67,45]}')
#
# ~/miniforge3/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     728         else:
#     729             if index is None or columns is None:
# --> 730                 raise ValueError("DataFrame constructor not properly called!")
#     731
#     732             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#
# ValueError: DataFrame constructor not properly called!

# %%
pd.DataFrame({"nombres": ["juan", "pepe"], "peso": [67,45]})
# Out:
#   nombres  peso
# 0    juan    67
# 1    pepe    45

# %% [markdown]
# > - Is there a way to get the data from the `url`
# > - just like ↓

# %%
{"nombres": ["juan", "pepe"], "peso": [67,45]}
# Out:
# {'nombres': ['juan', 'pepe'], 'peso': [67, 45]}

# %% [markdown]
# > - and not this ↓

# %%
b'{"nombres": ["juan", "pepe"], "peso": [67,45]}'
# Out:
# b'{"nombres": ["juan", "pepe"], "peso": [67,45]}'

# %% [markdown]
# > - Apply the discipline to find a `function()` within the object

# %%
res.json()
# Out:
# {'income': {'roger': 130, 'rafa': 127, 'nole': 154},
#  'titles': {'roger': 103, 'rafa': 90, 'nole': 86},
#  'grand slams': {'roger': 20, 'rafa': 21, 'nole': 20},
#  'turned professional': {'roger': 1998, 'rafa': 2001, 'nole': 2003},
#  'wins': {'roger': 1251, 'rafa': 1038, 'nole': 989},
#  'losses': {'roger': 275, 'rafa': 209, 'nole': 199}}

# %%
pd.DataFrame(res.json())
# Out:
#        income  titles  grand slams  turned professional  wins  losses
# roger     130     103           20                 1998  1251     275
# rafa      127      90           21                 2001  1038     209
# nole      154      86           20                 2003   989     199

# %% [markdown]
# ### Recap

# %%
res = requests.get(url='https://raw.githubusercontent.com/jsulopz/data/main/best_tennis_players_stats.json')

# %%
res.content
# Out:
# b'{"income":{"roger":130,"rafa":127,"nole":154},"titles":{"roger":103,"rafa":90,"nole":86},"grand slams":{"roger":20,"rafa":21,"nole":20},"turned professional":{"roger":1998,"rafa":2001,"nole":2003},"wins":{"roger":1251,"rafa":1038,"nole":989},"losses":{"roger":275,"rafa":209,"nole":199}}'

# %%
pd.DataFrame(res.content)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/24/tg28vxls25l9mjvqrnh0plc80000gn/T/ipykernel_34198/1980481689.py in <module>
# ----> 1 pd.DataFrame(res.content)
#
# ~/miniforge3/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     728         else:
#     729             if index is None or columns is None:
# --> 730                 raise ValueError("DataFrame constructor not properly called!")
#     731
#     732             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#
# ValueError: DataFrame constructor not properly called!

# %%
res.json()
# Out:
# {'income': {'roger': 130, 'rafa': 127, 'nole': 154},
#  'titles': {'roger': 103, 'rafa': 90, 'nole': 86},
#  'grand slams': {'roger': 20, 'rafa': 21, 'nole': 20},
#  'turned professional': {'roger': 1998, 'rafa': 2001, 'nole': 2003},
#  'wins': {'roger': 1251, 'rafa': 1038, 'nole': 989},
#  'losses': {'roger': 275, 'rafa': 209, 'nole': 199}}

# %%
pd.DataFrame(res.json())
# Out:
#        income  titles  grand slams  turned professional  wins  losses
# roger     130     103           20                 1998  1251     275
# rafa      127      90           21                 2001  1038     209
# nole      154      86           20                 2003   989     199

# %% [markdown]
# ### Shouldn't it be easier?

# %% [markdown]
# > - Apply the discipline to find `function()` within some library

# %%
pd.read_json('https://raw.githubusercontent.com/jsulopz/data/main/best_tennis_players_stats.json')
# Out:
#        income  titles  grand slams  turned professional  wins  losses
# roger     130     103           20                 1998  1251     275
# rafa      127      90           21                 2001  1038     209
# nole      154      86           20                 2003   989     199

# %%
df = pd.read_json('https://raw.githubusercontent.com/jsulopz/data/main/best_tennis_players_stats.json')

# %%
df
# Out:
#        income  titles  grand slams  turned professional  wins  losses
# roger     130     103           20                 1998  1251     275
# rafa      127      90           21                 2001  1038     209
# nole      154      86           20                 2003   989     199

# %% [markdown]
# > - And now calculate the `sum()` of the `income`

# %%
df.income.sum()
# Out:
# 411
