# %% [markdown]
# ### Retrieve IBM Stock Prices from an API

# %% [markdown]
# > - You may use the [AlphaVantage](https://www.alphavantage.co/documentation/) API

# %%
import requests
import pandas as pd

# %%
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=IBM&interval=5min&apikey=demo'
r = requests.get(url)
data = r.json()

# %%
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=IBM&interval=5min&apikey=C8LPFAAFFQXWNI9E'
r = requests.get(url)
data = r.json()

# %% [markdown]
# #### Convert the `dict` to a `DataFrame`

# %%
pd.DataFrame(data)
# Out:
#                                                              Meta Data  \
# 1. Information       Intraday (5min) open, high, low, close prices ...
# 2. Symbol                                                         TSLA
# 3. Last Refreshed                                  2022-02-14 20:00:00
# 4. Interval                                                       5min
# 5. Output Size                                                 Compact
# ...                                                                ...
# 2022-02-14 11:35:00                                                NaN
# 2022-02-14 11:30:00                                                NaN
# 2022-02-14 11:25:00                                                NaN
# 2022-02-14 11:20:00                                                NaN
# 2022-02-14 11:15:00                                                NaN
#
#                                                     Time Series (5min)
# ...

# %% [markdown]
# > - [ ] Is this how we expected the `DataFrame` to be?
# > - How did we expected?

# %% [markdown]
# ![](df.png)

# %% [markdown]
# > - [ ] How can we organize the information to be like the `DataFrame` above?
# > - Show solutions from 01 / 01

# %%
data.keys()
# Out:
# dict_keys(['Meta Data', 'Time Series (5min)'])

# %%
data['Meta Data']
# Out:
# {'1. Information': 'Intraday (5min) open, high, low, close prices and volume',
#  '2. Symbol': 'TSLA',
#  '3. Last Refreshed': '2022-02-14 20:00:00',
#  '4. Interval': '5min',
#  '5. Output Size': 'Compact',
#  '6. Time Zone': 'US/Eastern'}

# %%
data['Time Series (5min)']
# Out:
# {'2022-02-14 20:00:00': {'1. open': '876.5200',
#   '2. high': '880.4000',
#   '3. low': '876.5200',
#   '4. close': '880.0000',
#   '5. volume': '5326'},
#  '2022-02-14 19:50:00': {'1. open': '876.1300',
#   '2. high': '876.1300',
#   '3. low': '876.1300',
#   '4. close': '876.1300',
#   '5. volume': '411'},
#  '2022-02-14 19:45:00': {'1. open': '877.4500',
#   '2. high': '877.4500',
#   '3. low': '876.2500',
#   '4. close': '876.2500',
#   '5. volume': '2445'},
#  '2022-02-14 19:35:00': {'1. open': '878.1700',
#   '2. high': '878.1700',
#   '3. low': '877.5000',
#   '4. close': '877.5000',
#   '5. volume': '932'},
#  '2022-02-14 19:30:00': {'1. open': '877.5501',
#   '2. high': '877.5501',
#   '3. low': '877.5501',
#   '4. close': '877.5501',
#   '5. volume': '1000'},
#  '2022-02-14 19:25:00': {'1. open': '878.0000',
#   '2. high': '878.9400',
#   '3. low': '877.7000',
#   '4. close': '878.9400',
#   '5. volume': '1479'},
#  '2022-02-14 19:20:00': {'1. open': '878.5000',
# ...

# %%
diccionario_serie_temporal = data['Time Series (5min)']

# %%
pd.DataFrame(diccionario_serie_temporal)
# Out:
#           2022-02-14 20:00:00 2022-02-14 19:50:00 2022-02-14 19:45:00  \
# 1. open              876.5200            876.1300            877.4500
# 2. high              880.4000            876.1300            877.4500
# 3. low               876.5200            876.1300            876.2500
# 4. close             880.0000            876.1300            876.2500
# 5. volume                5326                 411                2445
#
#           2022-02-14 19:35:00 2022-02-14 19:30:00 2022-02-14 19:25:00  \
# 1. open              878.1700            877.5501            878.0000
# 2. high              878.1700            877.5501            878.9400
# 3. low               877.5000            877.5501            877.7000
# 4. close             877.5000            877.5501            878.9400
# 5. volume                 932                1000                1479
#
#           2022-02-14 19:20:00 2022-02-14 19:15:00 2022-02-14 19:05:00  \
# ...

# %%
df = pd.DataFrame(diccionario_serie_temporal)

# %%
df.transpose()
# Out:
#                       1. open   2. high    3. low  4. close 5. volume
# 2022-02-14 20:00:00  876.5200  880.4000  876.5200  880.0000      5326
# 2022-02-14 19:50:00  876.1300  876.1300  876.1300  876.1300       411
# 2022-02-14 19:45:00  877.4500  877.4500  876.2500  876.2500      2445
# 2022-02-14 19:35:00  878.1700  878.1700  877.5000  877.5000       932
# 2022-02-14 19:30:00  877.5501  877.5501  877.5501  877.5501      1000
# ...                       ...       ...       ...       ...       ...
# 2022-02-14 11:35:00  896.7172  897.0700  892.7100  896.0200    338442
# 2022-02-14 11:30:00  898.2100  898.8799  896.2101  896.5570    271036
# 2022-02-14 11:25:00  897.6150  898.8500  896.3400  898.4300    287288
# 2022-02-14 11:20:00  891.2100  898.5500  890.7500  897.6350    426660
# 2022-02-14 11:15:00  891.0001  893.2096  890.1100  891.0500    272430
#
# [100 rows x 5 columns]

# %%
df = df.transpose()

# %% [markdown]
# > - [ ] Create a **new column** that contains the name of the `ticker`

# %%
df['ticker'] = 'IBM'

# %%
df
# Out:
#                       1. open   2. high    3. low  4. close 5. volume ticker
# 2022-02-14 20:00:00  876.5200  880.4000  876.5200  880.0000      5326    IBM
# 2022-02-14 19:50:00  876.1300  876.1300  876.1300  876.1300       411    IBM
# 2022-02-14 19:45:00  877.4500  877.4500  876.2500  876.2500      2445    IBM
# 2022-02-14 19:35:00  878.1700  878.1700  877.5000  877.5000       932    IBM
# 2022-02-14 19:30:00  877.5501  877.5501  877.5501  877.5501      1000    IBM
# ...                       ...       ...       ...       ...       ...    ...
# 2022-02-14 11:35:00  896.7172  897.0700  892.7100  896.0200    338442    IBM
# 2022-02-14 11:30:00  898.2100  898.8799  896.2101  896.5570    271036    IBM
# 2022-02-14 11:25:00  897.6150  898.8500  896.3400  898.4300    287288    IBM
# 2022-02-14 11:20:00  891.2100  898.5500  890.7500  897.6350    426660    IBM
# 2022-02-14 11:15:00  891.0001  893.2096  890.1100  891.0500    272430    IBM
#
# [100 rows x 6 columns]

# %% [markdown]
# ### Summary All in Once

# %%
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=IBM&interval=5min&apikey=C8LPFAAFFQXWNI9E'
r = requests.get(url)
data = r.json()

diccionario_serie_temporal = data['Time Series (5min)']

df_IBM = pd.DataFrame(diccionario_serie_temporal)

df_IBM = df_IBM.transpose()

df_IBM['ticker'] = 'IBM'

df_IBM
# Out:
#                       1. open   2. high    3. low  4. close 5. volume ticker
# 2022-02-14 19:55:00  130.1500  130.1500  130.1500  130.1500       200    IBM
# 2022-02-14 19:50:00  130.1500  130.1500  130.1500  130.1500       313    IBM
# 2022-02-14 19:20:00  130.1700  130.1700  130.1700  130.1700       100    IBM
# 2022-02-14 18:50:00  130.3400  130.3400  130.3400  130.3400       100    IBM
# 2022-02-14 17:35:00  130.0000  130.0000  130.0000  130.0000       152    IBM
# ...                       ...       ...       ...       ...       ...    ...
# 2022-02-14 08:20:00  132.3800  132.3800  132.3600  132.3600      1785    IBM
# 2022-02-14 08:15:00  132.3600  132.3600  132.3600  132.3600       900    IBM
# 2022-02-14 08:05:00  131.0000  132.5000  131.0000  132.5000      1969    IBM
# 2022-02-14 08:00:00  132.1200  132.1200  132.1200  132.1200       137    IBM
# 2022-02-14 07:50:00  132.2500  132.2500  132.2500  132.2500       907    IBM
#
# [100 rows x 6 columns]

# %% [markdown]
# ### Get Stock Price for `AAPL`

# %%
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=AAPL&interval=5min&apikey=C8LPFAAFFQXWNI9E'
r = requests.get(url)
data = r.json()

diccionario_serie_temporal = data['Time Series (5min)']

df_AAPL = pd.DataFrame(diccionario_serie_temporal)

df_AAPL = df_AAPL.transpose()

df_AAPL['ticker'] = 'AAPL'

df_AAPL
# Out:
#                       1. open   2. high    3. low  4. close 5. volume ticker
# 2022-02-14 20:00:00  168.8000  168.8700  168.8000  168.8700      4133   AAPL
# 2022-02-14 19:55:00  168.8000  168.8100  168.8000  168.8001      1190   AAPL
# 2022-02-14 19:50:00  168.7200  168.7800  168.7000  168.7800      8273   AAPL
# 2022-02-14 19:45:00  168.7100  168.7700  168.7100  168.7400      1327   AAPL
# 2022-02-14 19:40:00  168.6900  168.7500  168.6300  168.7500      2579   AAPL
# ...                       ...       ...       ...       ...       ...    ...
# 2022-02-14 11:55:00  169.1100  169.2000  168.6000  168.6200    618635   AAPL
# 2022-02-14 11:50:00  168.8350  169.1500  168.8350  169.1050    561735   AAPL
# 2022-02-14 11:45:00  168.7646  169.1000  168.7100  168.8300    538022   AAPL
# 2022-02-14 11:40:00  168.9800  169.1600  168.5600  168.7700    779902   AAPL
# 2022-02-14 11:35:00  169.0000  169.1900  168.4700  168.9789   1242595   AAPL
#
# [100 rows x 6 columns]

# %% [markdown]
# ### Get Stock Price for `TSLA`

# %%
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=TSLA&interval=5min&apikey=C8LPFAAFFQXWNI9E'
r = requests.get(url)
data = r.json()

diccionario_serie_temporal = data['Time Series (5min)']

df_TSLA = pd.DataFrame(diccionario_serie_temporal)

df_TSLA = df_TSLA.transpose()

df_TSLA['ticker'] = 'TSLA'

df_TSLA

# %%
df_IBM
# Out:
#                       1. open   2. high    3. low  4. close 5. volume ticker
# 2022-02-14 19:55:00  130.1500  130.1500  130.1500  130.1500       200    IBM
# 2022-02-14 19:50:00  130.1500  130.1500  130.1500  130.1500       313    IBM
# 2022-02-14 19:20:00  130.1700  130.1700  130.1700  130.1700       100    IBM
# 2022-02-14 18:50:00  130.3400  130.3400  130.3400  130.3400       100    IBM
# 2022-02-14 17:35:00  130.0000  130.0000  130.0000  130.0000       152    IBM
# ...                       ...       ...       ...       ...       ...    ...
# 2022-02-14 08:20:00  132.3800  132.3800  132.3600  132.3600      1785    IBM
# 2022-02-14 08:15:00  132.3600  132.3600  132.3600  132.3600       900    IBM
# 2022-02-14 08:05:00  131.0000  132.5000  131.0000  132.5000      1969    IBM
# 2022-02-14 08:00:00  132.1200  132.1200  132.1200  132.1200       137    IBM
# 2022-02-14 07:50:00  132.2500  132.2500  132.2500  132.2500       907    IBM
#
# [100 rows x 6 columns]

# %%
df_AAPL
# Out:
#                       1. open   2. high    3. low  4. close 5. volume ticker
# 2022-02-14 20:00:00  168.8000  168.8700  168.8000  168.8700      4133   AAPL
# 2022-02-14 19:55:00  168.8000  168.8100  168.8000  168.8001      1190   AAPL
# 2022-02-14 19:50:00  168.7200  168.7800  168.7000  168.7800      8273   AAPL
# 2022-02-14 19:45:00  168.7100  168.7700  168.7100  168.7400      1327   AAPL
# 2022-02-14 19:40:00  168.6900  168.7500  168.6300  168.7500      2579   AAPL
# ...                       ...       ...       ...       ...       ...    ...
# 2022-02-14 11:55:00  169.1100  169.2000  168.6000  168.6200    618635   AAPL
# 2022-02-14 11:50:00  168.8350  169.1500  168.8350  169.1050    561735   AAPL
# 2022-02-14 11:45:00  168.7646  169.1000  168.7100  168.8300    538022   AAPL
# 2022-02-14 11:40:00  168.9800  169.1600  168.5600  168.7700    779902   AAPL
# 2022-02-14 11:35:00  169.0000  169.1900  168.4700  168.9789   1242595   AAPL
#
# [100 rows x 6 columns]

# %%
df_TSLA
# Out:
#                       1. open   2. high    3. low  4. close 5. volume ticker
# 2022-02-14 20:00:00  876.5200  880.4000  876.5200  880.0000      5326   TSLA
# 2022-02-14 19:50:00  876.1300  876.1300  876.1300  876.1300       411   TSLA
# 2022-02-14 19:45:00  877.4500  877.4500  876.2500  876.2500      2445   TSLA
# 2022-02-14 19:35:00  878.1700  878.1700  877.5000  877.5000       932   TSLA
# 2022-02-14 19:30:00  877.5501  877.5501  877.5501  877.5501      1000   TSLA
# ...                       ...       ...       ...       ...       ...    ...
# 2022-02-14 11:35:00  896.7172  897.0700  892.7100  896.0200    338442   TSLA
# 2022-02-14 11:30:00  898.2100  898.8799  896.2101  896.5570    271036   TSLA
# 2022-02-14 11:25:00  897.6150  898.8500  896.3400  898.4300    287288   TSLA
# 2022-02-14 11:20:00  891.2100  898.5500  890.7500  897.6350    426660   TSLA
# 2022-02-14 11:15:00  891.0001  893.2096  890.1100  891.0500    272430   TSLA
#
# [100 rows x 6 columns]

# %% [markdown]
# ### Put All `DataFrames` Together

# %%
df = pd.concat([df_AAPL, df_IBM, df_TSLA])

# %%
df
# Out:
#                       1. open   2. high    3. low  4. close 5. volume ticker
# 2022-02-14 20:00:00  168.8000  168.8700  168.8000  168.8700      4133   AAPL
# 2022-02-14 19:55:00  168.8000  168.8100  168.8000  168.8001      1190   AAPL
# 2022-02-14 19:50:00  168.7200  168.7800  168.7000  168.7800      8273   AAPL
# 2022-02-14 19:45:00  168.7100  168.7700  168.7100  168.7400      1327   AAPL
# 2022-02-14 19:40:00  168.6900  168.7500  168.6300  168.7500      2579   AAPL
# ...                       ...       ...       ...       ...       ...    ...
# 2022-02-14 11:35:00  896.7172  897.0700  892.7100  896.0200    338442   TSLA
# 2022-02-14 11:30:00  898.2100  898.8799  896.2101  896.5570    271036   TSLA
# 2022-02-14 11:25:00  897.6150  898.8500  896.3400  898.4300    287288   TSLA
# 2022-02-14 11:20:00  891.2100  898.5500  890.7500  897.6350    426660   TSLA
# 2022-02-14 11:15:00  891.0001  893.2096  890.1100  891.0500    272430   TSLA
#
# [300 rows x 6 columns]

# %% [markdown]
# ### How could we have applied a `for` loop for this?

# %%
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=TSLA&interval=5min&apikey=C8LPFAAFFQXWNI9E'
r = requests.get(url)
data = r.json()

diccionario_serie_temporal = data['Time Series (5min)']

df_TSLA = pd.DataFrame(diccionario_serie_temporal)

df_TSLA = df_TSLA.transpose()

df_TSLA['ticker'] = 'TSLA'

df_TSLA

# %%
    url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=TSLA&interval=5min&apikey=C8LPFAAFFQXWNI9E'
    r = requests.get(url)
    data = r.json()

    diccionario_serie_temporal = data['Time Series (5min)']

    df_TSLA = pd.DataFrame(diccionario_serie_temporal)

    df_TSLA = df_TSLA.transpose()

    df_TSLA['ticker'] = 'TSLA'

    df_TSLA

# %%
for ticker in ['IBM', 'AAPL', 'TSLA']:
    url = f'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol={ticker}&interval=5min&apikey=C8LPFAAFFQXWNI9E'
    r = requests.get(url)
    data = r.json()

    diccionario_serie_temporal = data['Time Series (5min)']

    df_ticker = pd.DataFrame(diccionario_serie_temporal)

    df_ticker = df.transpose()

    df_ticker['ticker'] = ticker

# %% [markdown]
# ### Calculate the Total `volume` for each Stock

# %%
df.groupby('ticker')['5. volume'].mean()
# Out:
# ticker
# AAPL    inf
# IBM     inf
# TSLA    inf
# Name: 5. volume, dtype: float64

# %%
df
# Out:
#                       1. open   2. high    3. low  4. close 5. volume ticker
# 2022-02-14 20:00:00  168.8000  168.8700  168.8000  168.8700      4133   AAPL
# 2022-02-14 19:55:00  168.8000  168.8100  168.8000  168.8001      1190   AAPL
# 2022-02-14 19:50:00  168.7200  168.7800  168.7000  168.7800      8273   AAPL
# 2022-02-14 19:45:00  168.7100  168.7700  168.7100  168.7400      1327   AAPL
# 2022-02-14 19:40:00  168.6900  168.7500  168.6300  168.7500      2579   AAPL
# ...                       ...       ...       ...       ...       ...    ...
# 2022-02-14 11:35:00  896.7172  897.0700  892.7100  896.0200    338442   TSLA
# 2022-02-14 11:30:00  898.2100  898.8799  896.2101  896.5570    271036   TSLA
# 2022-02-14 11:25:00  897.6150  898.8500  896.3400  898.4300    287288   TSLA
# 2022-02-14 11:20:00  891.2100  898.5500  890.7500  897.6350    426660   TSLA
# 2022-02-14 11:15:00  891.0001  893.2096  890.1100  891.0500    272430   TSLA
#
# [300 rows x 6 columns]

# %% [markdown]
# > - Check the `dtypes` of the columns

# %%
df.dtypes
# Out:
# 1. open      object
# 2. high      object
# 3. low       object
# 4. close     object
# 5. volume    object
# ticker       object
# dtype: object

# %% [markdown]
# > - [ ] How can we convert them to `numeric`?

# %%
df.iloc[:, :5] = df.iloc[:, :5].apply(pd.to_numeric)

# %% [markdown]
# > - Check the `dtypes` of the columns

# %%
df.dtypes
# Out:
# 1. open      object
# 2. high      object
# 3. low       object
# 4. close     object
# 5. volume    object
# ticker       object
# dtype: object

# %% [markdown]
# > - [ ] Could we compute the `sum()` of `volume` now?

# %%
df.groupby('ticker')['5. volume'].mean()
# Out:
# ticker
# AAPL    472030.07
# IBM      45203.00
# TSLA    126725.91
# Name: 5. volume, dtype: float64

# %% [markdown]
# ### Working with the Date

# %% [markdown]
# #### Get the hour and put it as new column

# %%
df.index
# Out:
# Index(['2022-02-14 20:00:00', '2022-02-14 19:55:00', '2022-02-14 19:50:00',
#        '2022-02-14 19:45:00', '2022-02-14 19:40:00', '2022-02-14 19:35:00',
#        '2022-02-14 19:30:00', '2022-02-14 19:25:00', '2022-02-14 19:20:00',
#        '2022-02-14 19:15:00',
#        ...
#        '2022-02-14 12:00:00', '2022-02-14 11:55:00', '2022-02-14 11:50:00',
#        '2022-02-14 11:45:00', '2022-02-14 11:40:00', '2022-02-14 11:35:00',
#        '2022-02-14 11:30:00', '2022-02-14 11:25:00', '2022-02-14 11:20:00',
#        '2022-02-14 11:15:00'],
#       dtype='object', length=300)

# %%
df.index.hour
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/24/tg28vxls25l9mjvqrnh0plc80000gn/T/ipykernel_8460/1302584992.py in <module>
# ----> 1 df.index.hour
#
# AttributeError: 'Index' object has no attribute 'hour'

# %%
df.index.date
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/24/tg28vxls25l9mjvqrnh0plc80000gn/T/ipykernel_8460/1034047442.py in <module>
# ----> 1 df.index.date
#
# AttributeError: 'Index' object has no attribute 'date'

# %%
pd.to_datetime(df.index)
# Out:
# DatetimeIndex(['2022-02-14 20:00:00', '2022-02-14 19:55:00',
#                '2022-02-14 19:50:00', '2022-02-14 19:45:00',
#                '2022-02-14 19:40:00', '2022-02-14 19:35:00',
#                '2022-02-14 19:30:00', '2022-02-14 19:25:00',
#                '2022-02-14 19:20:00', '2022-02-14 19:15:00',
#                ...
#                '2022-02-14 12:00:00', '2022-02-14 11:55:00',
#                '2022-02-14 11:50:00', '2022-02-14 11:45:00',
#                '2022-02-14 11:40:00', '2022-02-14 11:35:00',
#                '2022-02-14 11:30:00', '2022-02-14 11:25:00',
#                '2022-02-14 11:20:00', '2022-02-14 11:15:00'],
#               dtype='datetime64[ns]', length=300, freq=None)

# %%
df.index.month
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/24/tg28vxls25l9mjvqrnh0plc80000gn/T/ipykernel_8460/117292228.py in <module>
# ----> 1 df.index.month
#
# AttributeError: 'Index' object has no attribute 'month'

# %%
df.index
# Out:
# Index(['2022-02-14 20:00:00', '2022-02-14 19:55:00', '2022-02-14 19:50:00',
#        '2022-02-14 19:45:00', '2022-02-14 19:40:00', '2022-02-14 19:35:00',
#        '2022-02-14 19:30:00', '2022-02-14 19:25:00', '2022-02-14 19:20:00',
#        '2022-02-14 19:15:00',
#        ...
#        '2022-02-14 12:00:00', '2022-02-14 11:55:00', '2022-02-14 11:50:00',
#        '2022-02-14 11:45:00', '2022-02-14 11:40:00', '2022-02-14 11:35:00',
#        '2022-02-14 11:30:00', '2022-02-14 11:25:00', '2022-02-14 11:20:00',
#        '2022-02-14 11:15:00'],
#       dtype='object', length=300)

# %%
df.index = pd.to_datetime(df.index)

# %%
df.index
# Out:
# DatetimeIndex(['2022-02-14 20:00:00', '2022-02-14 19:55:00',
#                '2022-02-14 19:50:00', '2022-02-14 19:45:00',
#                '2022-02-14 19:40:00', '2022-02-14 19:35:00',
#                '2022-02-14 19:30:00', '2022-02-14 19:25:00',
#                '2022-02-14 19:20:00', '2022-02-14 19:15:00',
#                ...
#                '2022-02-14 12:00:00', '2022-02-14 11:55:00',
#                '2022-02-14 11:50:00', '2022-02-14 11:45:00',
#                '2022-02-14 11:40:00', '2022-02-14 11:35:00',
#                '2022-02-14 11:30:00', '2022-02-14 11:25:00',
#                '2022-02-14 11:20:00', '2022-02-14 11:15:00'],
#               dtype='datetime64[ns]', length=300, freq=None)

# %%
df.index.hour
# Out:
# Int64Index([20, 19, 19, 19, 19, 19, 19, 19, 19, 19,
#             ...
#             12, 11, 11, 11, 11, 11, 11, 11, 11, 11],
#            dtype='int64', length=300)

# %% [markdown]
# ## [ ] `Develop` script watching previous step

# %%
#Copy Paste Sketch **HERE**

# %% [markdown]
# ## [ ] Put the `script to rest` for a day

# %% [markdown]
# ## [ ] Review

# %%
#Copy Paste Complete Script **HERE**

# %% [markdown]
# ## [ ] Final `Title` ↓

# %% [markdown]
# ## [ ] Tags:
#
# 1. Machine Learning
# 2. Data Science
# 3. Data Visualization
# 4. Python
# 5. Pandas

# %% [markdown]
# ## [ ] Publish

# %%
# !jupyter nbconvert -TagRemovePreprocessor.remove_cell_tags='{"remove_cell"}' -TagRemovePreprocessor.remove_all_outputs_tags='{"remove_output"}' \
    -TagRemovePreprocessor.remove_input_tags='{"remove_input"}' --to markdown script.ipynb
# Out:
# [NbConvertApp] Converting notebook script.ipynb to markdown
# [NbConvertApp] Support files will be in script_files/
# [NbConvertApp] Making directory script_files
# [NbConvertApp] Making directory script_files
# [NbConvertApp] Writing 4640 bytes to script.md
