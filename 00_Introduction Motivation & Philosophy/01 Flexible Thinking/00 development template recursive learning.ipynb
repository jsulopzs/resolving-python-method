# %% [markdown]
# <font size="+5">#0x | Topic</font>

# %% [markdown]
# # The starting *thing*

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df = sns.load_dataset('car_crashes')
df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
plt.scatter(x=alcohol, y=total);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/24/tg28vxls25l9mjvqrnh0plc80000gn/T/ipykernel_9240/3933251502.py in <module>
# ----> 1 plt.scatter(x=alcohol, y=total);
#
# NameError: name 'alcohol' is not defined

# %% [markdown]
# # Don't think about the solution
#
# - Let's imagine
# - We've got two surgeons
#     - Joseph to diagnose the illness (error)
#     - Mary to operate (solve) the illnes
# - Would you remove Joseph from the equation?
# - Mary may operate the nose
# - But the illness is in the eyes...
# - This is why you should always focus in fully understanding the error first
#
# ## Solution:

# %%
alcohol
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/24/tg28vxls25l9mjvqrnh0plc80000gn/T/ipykernel_9240/2726447888.py in <module>
# ----> 1 alcohol
#
# NameError: name 'alcohol' is not defined

# %%
jesus
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/24/tg28vxls25l9mjvqrnh0plc80000gn/T/ipykernel_9240/3360255931.py in <module>
# ----> 1 jesus
#
# NameError: name 'jesus' is not defined

# %%
'alcohol'
# Out:
# 'alcohol'

# %%
'jesus'
# Out:
# 'jesus'

# %%
# - Solve the `error_3`

# %%
plt.scatter(x='alcohol', y=total);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/24/tg28vxls25l9mjvqrnh0plc80000gn/T/ipykernel_9240/1069158763.py in <module>
# ----> 1 plt.scatter(x='alcohol', y=total);
#
# NameError: name 'total' is not defined

# %%
plt.scatter(x='alcohol', y='total');

# %% [markdown]
# ## Error:

# %% [markdown]
# - [ ] Why don't we have all the points?

# %%
'alcohol'
# Out:
# 'alcohol'

# %%
'total'
# Out:
# 'total'

# %%
df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %% [markdown]
# # What you pass to the `function()` matters
#
# - The `function()` plays with
# - the `objects` passed
# - to the `parameters`
#
# ## Solution:

# %%
# - Solve the `error_1`

# %%
df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
plt.scatter(
    x=[5.64, 4.525, 5.208, 5.824, 3.360],
    y=[18.8, 18.1, 18.6, 22.4, 12.0]
);

# %% [markdown]
# ## Error:

# %%
# - Get an `error_2` from `solution_1`

# %% [markdown]
# - [ ] How can we pass all the values to the parameters without writing down all of them?

# %% [markdown]
# # `Instance` within an `instance`
#
# 1. Dot notation
# 2. Access `instances` within `instances`
#
# ## Solution:

# %%
# - Solve the `error_2`

# %%
df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
df.alcohol
# Out:
# 0      5.640
# 1      4.525
# 2      5.208
# 3      5.824
# 4      3.360
# 5      3.808
# 6      3.888
# 7      4.860
# 8      1.593
# 9      5.191
# 10     3.900
# 11     7.175
# 12     4.437
# 13     4.352
# 14     4.205
# 15     3.925
# 16     4.272
# 17     4.922
# 18     6.765
# 19     4.530
# 20     4.000
# 21     2.870
# 22     3.948
# 23     2.784
# 24     5.456
# 25     5.474
# 26     9.416
# 27     5.215
# 28     4.704
# 29     3.480
# 30     3.136
# 31     4.968
# 32     3.567
# 33     5.208
# 34    10.038
# 35     4.794
# 36     5.771
# 37     3.328
# 38     5.642
# 39     4.218
# 40     9.799
# 41     6.402
# 42     5.655
# 43     7.372
# 44     1.808
# 45     4.080
# 46     3.429
# 47     3.498
# 48     6.664
# 49     4.554
# 50     5.568
# Name: alcohol, dtype: float64

# %%
df.total
# Out:
# 0     18.8
# 1     18.1
# 2     18.6
# 3     22.4
# 4     12.0
# 5     13.6
# 6     10.8
# 7     16.2
# 8      5.9
# 9     17.9
# 10    15.6
# 11    17.5
# 12    15.3
# 13    12.8
# 14    14.5
# 15    15.7
# 16    17.8
# 17    21.4
# 18    20.5
# 19    15.1
# 20    12.5
# 21     8.2
# 22    14.1
# 23     9.6
# 24    17.6
# 25    16.1
# 26    21.4
# 27    14.9
# 28    14.7
# 29    11.6
# 30    11.2
# 31    18.4
# 32    12.3
# 33    16.8
# 34    23.9
# 35    14.1
# 36    19.9
# 37    12.8
# 38    18.2
# 39    11.1
# 40    23.9
# 41    19.4
# 42    19.5
# 43    19.4
# 44    11.3
# 45    13.6
# 46    12.7
# 47    10.6
# 48    23.8
# 49    13.8
# 50    17.4
# Name: total, dtype: float64

# %%
plt.scatter(x=df.alcohol, y=df.total);

# %% [markdown]
# ## Error:

# %%
# - Get an `error_3` from `solution_2`

# %% [markdown]
# # Concept needed for `error_3`
#
# 1. Element 1
# 2. Element 2
# 3. Element …
#
# ## Solution:

# %%
# - Solve the `error_3`

# %% [markdown]
# ## Error:

# %%
# - Get an `error_x` from `solution_3`

# %% [markdown]
# # The uncovered solution

# %% [markdown]
# # What have we learnt?
#
# ## Fundamental Teaching 1

# %% [markdown]
# ## Fundamental Teaching 2

# %% [markdown]
# # Define the concepts ↓
#
# - Fundamental Concept 1:
#
# ---
#
# - Fundamental Concept 2:
#
# ---
