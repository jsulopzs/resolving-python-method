# %% [markdown]
# # Discipline

# %% [markdown]
# cuando me enfrento a un problema...
#
# 1. identifico el problema
# 2. observo el objeto del que parto

# %%
texto = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=IBM&interval=5min&apikey=C8LPFAAFFQXWNI9E'

# %%
type(texto)
# Out:
# str

# %% [markdown]
# 3. habria alguna funcion dentro del objeto `str` que me permita obtener la informacion de la url
#     - aunque python no sepa que esto es una `url`

# %%
texto
# Out:
# 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=IBM&interval=5min&apikey=C8LPFAAFFQXWNI9E'

# %%
texto.title()
# Out:
# 'Https://Www.Alphavantage.Co/Query?Function=Time_Series_Intraday&Symbol=Ibm&Interval=5Min&Apikey=C8Lpfaaffqxwni9E'

# %% [markdown]
# 4. esta claro que el `str` es un objeto muy simple
# 5. como para que tenga una funcion que se conecte a internet
# 6. y me pille los datos que estan en la url...
#
# 7. entonces?
# 8. voy a google a buscar la funcion que me permite extraer datos de una url
# 9. al pasarle un `str`

# %%
import urllib

link = "https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=IBM&interval=5min&apikey=C8LPFAAFFQXWNI9E"
f = urllib.urlopen(link)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/24/tg28vxls25l9mjvqrnh0plc80000gn/T/ipykernel_32963/3747648500.py in <module>
#       2
#       3 link = "https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=IBM&interval=5min&apikey=C8LPFAAFFQXWNI9E"
# ----> 4 f = urllib.urlopen(link)
#
# AttributeError: module 'urllib' has no attribute 'urlopen'

# %% [markdown]
# 10. he encontrado esta funcion
# 11. identifico lo que el tiene para cambiarlo a mi problema
# 12. no hace falta copiar todo...
# 13. solo la funcion y la libreria contenida en la funcion

# %%
import requests

link = "https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=IBM&interval=5min&apikey=C8LPFAAFFQXWNI9E"
f = requests.get(link)

# %%
f
# Out:
# <Response [200]>

# %% [markdown]
# 14. la funcion me devuelve un objeto
# 15. que yo lo guardo en la variable f
# 16. yo se que un objeto es una estrucutra de datos
# 17. aunque me aparezca `<Response [200]>`
# 18. yo se que el este objeto tiene mas informacion que eso...
# 19. sabiendo nociones basicas de la syntaxis de python **DOT NOTATION**
# 20. me meto dentro del objeto a ver que propiedades tiene...

# %%
f.

# %% [markdown]
# 21. me aparec una lista tras darle al tabulador
# 22. esta lista contiene las funciones y datos del objeto
# 23. por descarte/deduccion podria encontrar aquel
# 24. que me devuelve los datos de la url...

# %%
import pandas as pd

# %%
f_json = f.json()

# %%
['Time Series (5min)']
# Out:
# ['Time Series (5min)']

# %%
f_json['Time Series (5min)']
# Out:
# {'2022-02-09 20:00:00': {'1. open': '137.7900',
#   '2. high': '137.7900',
#   '3. low': '137.7900',
#   '4. close': '137.7900',
#   '5. volume': '347'},
#  '2022-02-09 19:55:00': {'1. open': '137.7900',
#   '2. high': '137.7900',
#   '3. low': '137.7900',
#   '4. close': '137.7900',
#   '5. volume': '154'},
#  '2022-02-09 19:50:00': {'1. open': '137.8000',
#   '2. high': '137.8000',
#   '3. low': '137.7900',
#   '4. close': '137.7900',
#   '5. volume': '407'},
#  '2022-02-09 19:45:00': {'1. open': '137.8000',
#   '2. high': '137.8000',
#   '3. low': '137.8000',
#   '4. close': '137.8000',
#   '5. volume': '146'},
#  '2022-02-09 19:40:00': {'1. open': '137.8000',
#   '2. high': '137.8000',
#   '3. low': '137.8000',
#   '4. close': '137.8000',
#   '5. volume': '100'},
#  '2022-02-09 19:35:00': {'1. open': '137.8300',
#   '2. high': '137.8300',
#   '3. low': '137.8300',
#   '4. close': '137.8300',
#   '5. volume': '200'},
#  '2022-02-09 19:25:00': {'1. open': '137.8000',
# ...

# %%
pd.DataFrame(f_json)
# Out:
#                                                              Meta Data  \
# 1. Information       Intraday (5min) open, high, low, close prices ...
# 2. Symbol                                                          IBM
# 3. Last Refreshed                                  2022-02-09 20:00:00
# 4. Interval                                                       5min
# 5. Output Size                                                 Compact
# ...                                                                ...
# 2022-02-09 09:45:00                                                NaN
# 2022-02-09 09:40:00                                                NaN
# 2022-02-09 09:35:00                                                NaN
# 2022-02-09 09:30:00                                                NaN
# 2022-02-09 09:05:00                                                NaN
#
#                                                     Time Series (5min)
# ...

# %%
['Time Series (5min)']
# Out:
# ['Time Series (5min)']

# %%
f_json['Time Series (5min)']
# Out:
# {'2022-02-09 20:00:00': {'1. open': '137.7900',
#   '2. high': '137.7900',
#   '3. low': '137.7900',
#   '4. close': '137.7900',
#   '5. volume': '347'},
#  '2022-02-09 19:55:00': {'1. open': '137.7900',
#   '2. high': '137.7900',
#   '3. low': '137.7900',
#   '4. close': '137.7900',
#   '5. volume': '154'},
#  '2022-02-09 19:50:00': {'1. open': '137.8000',
#   '2. high': '137.8000',
#   '3. low': '137.7900',
#   '4. close': '137.7900',
#   '5. volume': '407'},
#  '2022-02-09 19:45:00': {'1. open': '137.8000',
#   '2. high': '137.8000',
#   '3. low': '137.8000',
#   '4. close': '137.8000',
#   '5. volume': '146'},
#  '2022-02-09 19:40:00': {'1. open': '137.8000',
#   '2. high': '137.8000',
#   '3. low': '137.8000',
#   '4. close': '137.8000',
#   '5. volume': '100'},
#  '2022-02-09 19:35:00': {'1. open': '137.8300',
#   '2. high': '137.8300',
#   '3. low': '137.8300',
#   '4. close': '137.8300',
#   '5. volume': '200'},
#  '2022-02-09 19:25:00': {'1. open': '137.8000',
# ...

# %%
pd.DataFrame(f_json['Time Series (5min)'])
# Out:
#           2022-02-09 20:00:00 2022-02-09 19:55:00 2022-02-09 19:50:00  \
# 1. open              137.7900            137.7900            137.8000
# 2. high              137.7900            137.7900            137.8000
# 3. low               137.7900            137.7900            137.7900
# 4. close             137.7900            137.7900            137.7900
# 5. volume                 347                 154                 407
#
#           2022-02-09 19:45:00 2022-02-09 19:40:00 2022-02-09 19:35:00  \
# 1. open              137.8000            137.8000            137.8300
# 2. high              137.8000            137.8000            137.8300
# 3. low               137.8000            137.8000            137.8300
# 4. close             137.8000            137.8000            137.8300
# 5. volume                 146                 100                 200
#
#           2022-02-09 19:25:00 2022-02-09 19:20:00 2022-02-09 19:15:00  \
# ...

# %%
df = pd.DataFrame(f_json['Time Series (5min)'])

# %%
df.transpose()
# Out:
#                       1. open   2. high    3. low  4. close 5. volume
# 2022-02-09 20:00:00  137.7900  137.7900  137.7900  137.7900       347
# 2022-02-09 19:55:00  137.7900  137.7900  137.7900  137.7900       154
# 2022-02-09 19:50:00  137.8000  137.8000  137.7900  137.7900       407
# 2022-02-09 19:45:00  137.8000  137.8000  137.8000  137.8000       146
# 2022-02-09 19:40:00  137.8000  137.8000  137.8000  137.8000       100
# ...                       ...       ...       ...       ...       ...
# 2022-02-09 09:45:00  137.3080  137.7400  137.1800  137.6700     45342
# 2022-02-09 09:40:00  136.9600  137.3900  136.9600  137.2750     51247
# 2022-02-09 09:35:00  137.8400  137.8780  136.8300  136.9390    144767
# 2022-02-09 09:30:00  138.0000  138.0000  138.0000  138.0000       280
# 2022-02-09 09:05:00  137.8900  137.8900  137.8900  137.8900       100
#
# [100 rows x 5 columns]

# %%
f.content
# Out:
# b'{\n    "Meta Data": {\n        "1. Information": "Intraday (5min) open, high, low, close prices and volume",\n        "2. Symbol": "IBM",\n        "3. Last Refreshed": "2022-02-09 20:00:00",\n        "4. Interval": "5min",\n        "5. Output Size": "Compact",\n        "6. Time Zone": "US/Eastern"\n    },\n    "Time Series (5min)": {\n        "2022-02-09 20:00:00": {\n            "1. open": "137.7900",\n            "2. high": "137.7900",\n            "3. low": "137.7900",\n            "4. close": "137.7900",\n            "5. volume": "347"\n        },\n        "2022-02-09 19:55:00": {\n            "1. open": "137.7900",\n            "2. high": "137.7900",\n            "3. low": "137.7900",\n            "4. close": "137.7900",\n            "5. volume": "154"\n        },\n        "2022-02-09 19:50:00": {\n            "1. open": "137.8000",\n            "2. high": "137.8000",\n            "3. low": "137.7900",\n            "4. close": "137.7900",\n            "5. volume": "407"\n     
# ...

# %%
pd.DataFrame(f.content)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/24/tg28vxls25l9mjvqrnh0plc80000gn/T/ipykernel_32963/3301291067.py in <module>
# ----> 1 pd.DataFrame(f.content)
#
# ~/miniforge3/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     728         else:
#     729             if index is None or columns is None:
# --> 730                 raise ValueError("DataFrame constructor not properly called!")
#     731
#     732             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#
# ValueError: DataFrame constructor not properly called!

# %%
a = f.content

# %%
type(a)
# Out:
# bytes
